# %% [markdown]
# # Los datos trimestrales del último año para Malta

# %% [markdown]
# Procesamiento y Analisis exploratorio de datos
# * listings17sep23.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datos = pd.read_csv(r'C:\Users\kervi\OneDrive\Escritorio\DATA\proyecto modulo 2\17 septiembre 2023\listings17sep23.csv')

# %%
datos.shape # ver filas y columnas
# Out:
# (9999, 18)

# %%
datos
# Out:
#                       id                                               name  \
# 0                  50188  Villa in Ix-Xewkija · ★4.88 · 3 bedrooms · 3 b...
# 1                 102120  Home in Għajnsielem · ★4.77 · 4 bedrooms · 7 b...
# 2                 109123  Rental unit in Nadur, · ★4.80 · 2 bedrooms · 3...
# 3                 113998  Rental unit in Floriana · ★4.67 · 1 bedroom · ...
# 4                 114044  Condo in Ta' Xbiex · ★4.89 · 1 bedroom · 1 bed...
# ...                  ...                                                ...
# 9994  981052644241873573  Rental unit in St. Julian's · ★New · 1 bedroom...
# 9995  981082568292770946  Rental unit in Is-Swieqi · ★New · 2 bedrooms ·...
# 9996  981392323738493738  Rental unit in St. Julian's · ★New · 1 bedroom...
# 9997  981396676186644060  Rental unit in Il-Gżira · ★New · 1 bedroom · 1...
# 9998  981397592905623597  Rental unit in St. Julian's · ★New · 1 bedroom...
#
#         host_id      host_name  neighbourhood_group neighbourhood   latitude  \
# 0      45357098      Alexandra                  NaN       Xewkija  36.030350
# 1        534091        Michael                  NaN   Ghajnsielem  36.027230
# 2        560039  Lino And Rose                  NaN         Nadur  36.038200
# 3        578865           Alan                  NaN      Floriana  35.892780
# 4        578994           Paul                  NaN     Ta' Xbiex  35.899770
# ...         ...            ...                  ...           ...        ...
# 9994  389001519          Maria                  NaN    San Giljan  35.917626
# 9995  537263548         Amanda                  NaN        Swieqi  35.922164
# 9996  537327763        Sergejs                  NaN    San Giljan  35.921424
# 9997   65060258          Mandy                  NaN         Gzira  35.904930
# 9998  537327763        Sergejs                  NaN    San Giljan  35.911288
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0     14.255800  Entire home/apt    150               4                178
# 1     14.287500  Entire home/apt    104               3                 38
# 2     14.289390  Entire home/apt     50               4                111
# 3     14.503960  Entire home/apt     58               6                202
# 4     14.492230     Private room     60               2                 83
# ...         ...              ...    ...             ...                ...
# 9994  14.490220     Private room     60               1                  0
# 9995  14.484010  Entire home/apt    105               1                  0
# 9996  14.490587     Private room     60               1                  0
# 9997  14.491220     Private room    125               1                  0
# 9998  14.486028     Private room     60               1                  0
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 0     2023-07-17               1.33                               1
# 1     2023-09-01               0.28                               7
# 2     2023-09-09               0.82                               3
# 3     2023-08-31               1.36                               7
# 4     2023-09-08               0.97                               2
# ...          ...                ...                             ...
# 9994         NaN                NaN                               2
# 9995         NaN                NaN                               1
# 9996         NaN                NaN                               2
# 9997         NaN                NaN                               5
# 9998         NaN                NaN                               2
#
#       availability_365  number_of_reviews_ltm  license
# 0                  283                     12      NaN
# 1                  328                      7      NaN
# 2                    0                     10      NaN
# 3                  143                     12      NaN
# 4                  364                     22      NaN
# ...                ...                    ...      ...
# 9994               257                      0      NaN
# 9995               359                      0      NaN
# 9996               257                      0      NaN
# 9997               269                      0      NaN
# 9998               257                      0      NaN
#
# [9999 rows x 18 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              9999 non-null   int64
#  1   name                            9999 non-null   object
#  2   host_id                         9999 non-null   int64
#  3   host_name                       9999 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   9999 non-null   object
#  6   latitude                        9999 non-null   float64
#  7   longitude                       9999 non-null   float64
#  8   room_type                       9999 non-null   object
#  9   price                           9999 non-null   int64
#  10  minimum_nights                  9999 non-null   int64
#  11  number_of_reviews               9999 non-null   int64
#  12  last_review                     8273 non-null   object
#  13  reviews_per_month               8273 non-null   float64
#  14  calculated_host_listings_count  9999 non-null   int64
#  15  availability_365                9999 non-null   int64
#  16  number_of_reviews_ltm           9999 non-null   int64
#  17  license                         0 non-null      float64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 1.4+ MB

# %%
datos.shape # ver filas y columnas
# Out:
# (9999, 18)

# %%
datos.columns #ver columnas
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
sns.heatmap(datos.isnull(), cbar=False) # nulos
# Out:
# <Axes: >

# %% [markdown]
# ### limpiar base ( nulos y reparar datos)

# %% [markdown]
# * datos faltantes en algunas celdas
# * columnas irrelevantes
# * registros (filas) repetidas
# * errores tipograficos en caso de variaables categoricas
# * valores extremos (outliers)

# %%
cols_cat = ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
       'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'number_of_reviews', 'last_review',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365', 'number_of_reviews_ltm', 'license']  # columnas de datos

for col in cols_cat:
    print(f'columna ¨{col}: ¨{datos[col].nunique()} subniveles') #subniveles de columnas
# Out:
# columna ¨id: ¨9999 subniveles
# columna ¨name: ¨8207 subniveles
# columna ¨host_id: ¨3826 subniveles
# columna ¨host_name: ¨1842 subniveles
# columna ¨neighbourhood_group: ¨0 subniveles
# columna ¨neighbourhood: ¨68 subniveles
# columna ¨latitude: ¨7650 subniveles
# columna ¨longitude: ¨8034 subniveles
# columna ¨room_type: ¨4 subniveles
# columna ¨price: ¨486 subniveles
# columna ¨minimum_nights: ¨33 subniveles
# columna ¨number_of_reviews: ¨272 subniveles
# columna ¨last_review: ¨851 subniveles
# columna ¨reviews_per_month: ¨523 subniveles
# columna ¨calculated_host_listings_count: ¨49 subniveles
# columna ¨availability_365: ¨366 subniveles
# columna ¨number_of_reviews_ltm: ¨83 subniveles
# columna ¨license: ¨0 subniveles

# %%
def nulos_y_porcentaje(datos):
    # Calcula el número de valores nulos por columna
    nulos_por_columna = datos.isnull().sum()
    
    # Calcula el total de filas
    total_filas = len(datos)
    
    # Calcula el porcentaje de nulos por columna
    porcentaje_nulos_por_columna = (nulos_por_columna / total_filas) * 100
    
    # Calcula el porcentaje de filas con valores nulos en su respectiva columna
    porcentaje_filas_con_nulos_por_columna = (nulos_por_columna / total_filas) * 100
    
    return nulos_por_columna, porcentaje_filas_con_nulos_por_columna

# Calcula el número de valores nulos por columna y el porcentaje de filas con valores nulos por columna
nulos_por_columna, porcentaje_filas_con_nulos_por_columna = nulos_y_porcentaje(datos)

# Imprime los resultados
print("Número de valores nulos por columna:")
print(nulos_por_columna)
print("\nPorcentaje de filas con valores nulos en su respectiva columna:")
print(porcentaje_filas_con_nulos_por_columna)
# Out:
# Número de valores nulos por columna:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group               9999
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1726
# reviews_per_month                 1726
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           9999
# dtype: int64
#
# Porcentaje de filas con valores nulos en su respectiva columna:
# id                                  0.000000
# name                                0.000000
# host_id                             0.000000
# host_name                           0.000000
# neighbourhood_group               100.000000
# neighbourhood                       0.000000
# latitude                            0.000000
# longitude                           0.000000
# room_type                           0.000000
# price                               0.000000
# minimum_nights                      0.000000
# number_of_reviews                   0.000000
# last_review                        17.261726
# reviews_per_month                  17.261726
# calculated_host_listings_count      0.000000
# availability_365                    0.000000
# number_of_reviews_ltm               0.000000
# license                           100.000000
# dtype: float64

# %%
# Define la función para eliminar columnas con valores nulos mayores al 60%
def eliminar_columnas_con_nulos(df, umbral=16):
    # Calcula el porcentaje de valores nulos por columna
    porcentaje_nulos_por_columna = (df.isnull().sum() / len(df)) * 100
    
    # Encuentra las columnas que tienen valores nulos mayores al umbral especificado
    columnas_a_eliminar = porcentaje_nulos_por_columna[porcentaje_nulos_por_columna > umbral].index
    
    # Elimina las columnas con valores nulos mayores al umbral
    df_sin_columnas_nulas = df.drop(columns=columnas_a_eliminar)
    
    return df_sin_columnas_nulas

# Elimina las columnas con valores nulos mayores al 60%
datos_sin_columnas_nulas = eliminar_columnas_con_nulos(datos, umbral=16)

# Imprime los datos restantes para visualización
print("Datos después de eliminar columnas con valores nulos mayores al 16%:")
print(datos_sin_columnas_nulas)
# Out:
# Datos después de eliminar columnas con valores nulos mayores al 16%:
#                       id                                               name  \
# 0                  50188  Villa in Ix-Xewkija · ★4.88 · 3 bedrooms · 3 b...
# 1                 102120  Home in Għajnsielem · ★4.77 · 4 bedrooms · 7 b...
# 2                 109123  Rental unit in Nadur, · ★4.80 · 2 bedrooms · 3...
# 3                 113998  Rental unit in Floriana · ★4.67 · 1 bedroom · ...
# 4                 114044  Condo in Ta' Xbiex · ★4.89 · 1 bedroom · 1 bed...
# ...                  ...                                                ...
# 9994  981052644241873573  Rental unit in St. Julian's · ★New · 1 bedroom...
# 9995  981082568292770946  Rental unit in Is-Swieqi · ★New · 2 bedrooms ·...
# 9996  981392323738493738  Rental unit in St. Julian's · ★New · 1 bedroom...
# 9997  981396676186644060  Rental unit in Il-Gżira · ★New · 1 bedroom · 1...
# 9998  981397592905623597  Rental unit in St. Julian's · ★New · 1 bedroom...
#
#         host_id      host_name neighbourhood   latitude  longitude  \
# 0      45357098      Alexandra       Xewkija  36.030350  14.255800
# 1        534091        Michael   Ghajnsielem  36.027230  14.287500
# 2        560039  Lino And Rose         Nadur  36.038200  14.289390
# 3        578865           Alan      Floriana  35.892780  14.503960
# 4        578994           Paul     Ta' Xbiex  35.899770  14.492230
# ...         ...            ...           ...        ...        ...
# 9994  389001519          Maria    San Giljan  35.917626  14.490220
# 9995  537263548         Amanda        Swieqi  35.922164  14.484010
# 9996  537327763        Sergejs    San Giljan  35.921424  14.490587
# 9997   65060258          Mandy         Gzira  35.904930  14.491220
# 9998  537327763        Sergejs    San Giljan  35.911288  14.486028
#
#             room_type  price  minimum_nights  number_of_reviews  \
# 0     Entire home/apt    150               4                178
# 1     Entire home/apt    104               3                 38
# 2     Entire home/apt     50               4                111
# 3     Entire home/apt     58               6                202
# 4        Private room     60               2                 83
# ...               ...    ...             ...                ...
# 9994     Private room     60               1                  0
# 9995  Entire home/apt    105               1                  0
# 9996     Private room     60               1                  0
# 9997     Private room    125               1                  0
# 9998     Private room     60               1                  0
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                                  1               283                     12
# 1                                  7               328                      7
# 2                                  3                 0                     10
# 3                                  7               143                     12
# 4                                  2               364                     22
# ...                              ...               ...                    ...
# 9994                               2               257                      0
# 9995                               1               359                      0
# 9996                               2               257                      0
# 9997                               5               269                      0
# 9998                               2               257                      0
#
# [9999 rows x 14 columns]

# %%
# Guarda el DataFrame limpio en un nuevo archivo CSV
# Reemplaza 'ruta_datos_limpios.csv' con el nombre de archivo que desees
datos_sin_columnas_nulas.to_csv('ruta2_datos_limpios.csv', index=False)

print("CSV limpio guardado correctamente.")
# Out:
# CSV limpio guardado correctamente.

# %%
# Carga tus datos en un DataFrame de Pandas
# Reemplaza 'ruta_del_archivo.csv' con la ruta de tu archivo de datos
dato = pd.read_csv(r'C:\Users\kervi\OneDrive\Escritorio\DATA\proyecto modulo 2\ruta2_datos_limpios.csv')

# %%
dato
# Out:
#                       id                                               name  \
# 0                  50188  Villa in Ix-Xewkija · ★4.88 · 3 bedrooms · 3 b...
# 1                 102120  Home in Għajnsielem · ★4.77 · 4 bedrooms · 7 b...
# 2                 109123  Rental unit in Nadur, · ★4.80 · 2 bedrooms · 3...
# 3                 113998  Rental unit in Floriana · ★4.67 · 1 bedroom · ...
# 4                 114044  Condo in Ta' Xbiex · ★4.89 · 1 bedroom · 1 bed...
# ...                  ...                                                ...
# 9994  981052644241873573  Rental unit in St. Julian's · ★New · 1 bedroom...
# 9995  981082568292770946  Rental unit in Is-Swieqi · ★New · 2 bedrooms ·...
# 9996  981392323738493738  Rental unit in St. Julian's · ★New · 1 bedroom...
# 9997  981396676186644060  Rental unit in Il-Gżira · ★New · 1 bedroom · 1...
# 9998  981397592905623597  Rental unit in St. Julian's · ★New · 1 bedroom...
#
#         host_id      host_name neighbourhood   latitude  longitude  \
# 0      45357098      Alexandra       Xewkija  36.030350  14.255800
# 1        534091        Michael   Ghajnsielem  36.027230  14.287500
# 2        560039  Lino And Rose         Nadur  36.038200  14.289390
# 3        578865           Alan      Floriana  35.892780  14.503960
# 4        578994           Paul     Ta' Xbiex  35.899770  14.492230
# ...         ...            ...           ...        ...        ...
# 9994  389001519          Maria    San Giljan  35.917626  14.490220
# 9995  537263548         Amanda        Swieqi  35.922164  14.484010
# 9996  537327763        Sergejs    San Giljan  35.921424  14.490587
# 9997   65060258          Mandy         Gzira  35.904930  14.491220
# 9998  537327763        Sergejs    San Giljan  35.911288  14.486028
#
#             room_type  price  minimum_nights  number_of_reviews  \
# 0     Entire home/apt    150               4                178
# 1     Entire home/apt    104               3                 38
# 2     Entire home/apt     50               4                111
# 3     Entire home/apt     58               6                202
# 4        Private room     60               2                 83
# ...               ...    ...             ...                ...
# 9994     Private room     60               1                  0
# 9995  Entire home/apt    105               1                  0
# 9996     Private room     60               1                  0
# 9997     Private room    125               1                  0
# 9998     Private room     60               1                  0
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                                  1               283                     12
# 1                                  7               328                      7
# 2                                  3                 0                     10
# 3                                  7               143                     12
# 4                                  2               364                     22
# ...                              ...               ...                    ...
# 9994                               2               257                      0
# 9995                               1               359                      0
# 9996                               2               257                      0
# 9997                               5               269                      0
# 9998                               2               257                      0
#
# [9999 rows x 14 columns]

# %% [markdown]
# #  datos
#
# datos.shape # ver filas y columnas
#
# sns.heatmap(datos.isnull(), cbar=False) # nulos
