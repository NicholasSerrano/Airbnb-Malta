# %% [markdown]
# # Graficos proyecto 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
datos = pd.read_excel(r'C:\Users\kervi\OneDrive\Escritorio\DATA\MODULO_2\proyecto_modulo_2\data_Bi_P2\data_listings17sep23_Bi.xlsx')

# %%
datos.shape # ver filas y columnas
# Out:
# (10001, 14)

# %%
datos
# Out:
#            identificación                                             nombre  \
# 0                     NaN                                                NaN
# 1                      id                                               name
# 2                   50188  Villa in Ix-Xewkija · ★4.88 · 3 bedrooms · 3 b...
# 3                  102120  Home in Għajnsielem · ★4.77 · 4 bedrooms · 7 b...
# 4                  109123  Rental unit in Nadur, · ★4.80 · 2 bedrooms · 3...
# ...                   ...                                                ...
# 9996   981052644241873573  Rental unit in St. Julian's · ★New · 1 bedroom...
# 9997   981082568292770946  Rental unit in Is-Swieqi · ★New · 2 bedrooms ·...
# 9998   981392323738493738  Rental unit in St. Julian's · ★New · 1 bedroom...
# 9999   981396676186644060  Rental unit in Il-Gżira · ★New · 1 bedroom · 1...
# 10000  981397592905623597  Rental unit in St. Julian's · ★New · 1 bedroom...
#
# ...

# %% [markdown]
# ## Graficos

# %%
# gráfico de barras con colores
fig = px.bar(datos, x='vecindario', y='precio', color='vecindario', title='Distribución de precios por vecindario')

# Mostrar el gráfico
fig.show()

# %%
datos.columns
# Out:
# Index(['identificación', 'nombre', 'identificación del host', 'nombre_host',
#        'vecindario', 'latitude', 'longitude', 'tipo de habitación', 'precio',
#        'noches_mínimo', 'número_de_reseñas',
#        'recuento calculado de listados de anfitriones', 'disponibilidad_365',
#        'número de reseñas ltm'],
#       dtype='object')
